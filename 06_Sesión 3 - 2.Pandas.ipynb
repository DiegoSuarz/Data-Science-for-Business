# %% [markdown]
# # <u>Librería Pandas</u>

# %% [markdown]
#  La librería Pandas desarrollada para el análisis. Fue desarrollada en NumPy. La librería Pandas trae la riqueza de R al mundo de Python. Tiene eficiente estructuras de datos para procesar los datos, unir datos y leerlos de varias fuentes.

# %%
# Importar la librería Pandas desde Python.
import pandas as pd
import numpy as np

# %% [markdown]
# ## Series

# %% [markdown]
# Una **serie** en Pandas es un vector unidimensional con un índice que puede especificarse o no.
#
# El objeto `Series` es básicamente igual que un arreglo unidimensional NumPy. **La diferencia esencial es la presencia del índice**: mientras que el arreglo NumPy tiene un índice entero implícitamente definido, usado para acceder a los valores, la serie Pandas tiene un índice explícitamente definido con valores.

# %%
# Creación de una serie a partir de 10 números aleatorios.
# Una serie es un vector unidemensional
a = pd.Series(np.random.randint(0,10,10))
a
# Out:
# 0    5
# 1    2
# 2    0
# 3    9
# 4    0
# 5    5
# 6    5
# 7    5
# 8    6
# 9    2
# dtype: int32

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
# establecer un indice a la serie
ser_1 = pd.Series(np.random.randint(0,10,10), index=['a','b','c','d','e','f','g','h','i','j'])

# también se puede crear una serie desde un diccionario pd.Series({'idx1': val1, 'idx2': val2}

# %%
ser_1
# Out:
# a    9
# b    5
# c    7
# d    1
# e    4
# f    0
# g    4
# h    2
# i    1
# j    8
# dtype: int32

# %% [markdown]
# Como vemos en el resultado de la celda anterior, la Serie contiene una secuencia de valores y una secuencia de índices, a las cuales podemos acceder con los atributos `values` y `index`. Los valores son simplemente un arreglo de NumPy:

# %%
ser_1.values
# Out:
# array([9, 5, 7, 1, 4, 0, 4, 2, 1, 8])

# %% [markdown]
# El índice es un objeto tipo arreglo.

# %%
ser_1.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j'], dtype='object')

# %% [markdown]
# Al igual que con un arreglo NumPy, los datos pueden ser accedidos por el índice asociado, haciendo uso de los corchetes:

# %%
ser_1[2] # indexing
# Out:
# C:\Users\dg_su\AppData\Local\Temp\ipykernel_19368\2221920228.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ser_1[2] # indexing
# 7

# %%
ser_1[1:4] # slicing
# Out:
# b    5
# c    7
# d    1
# dtype: int32

# %%
print('Suma: ')
print(ser_1.sum())
print('Promedio: ')
print(ser_1.mean())
print('Mediana: ')
print(ser_1.median())
print('Mínimo: ')
print(ser_1.min())
print('Máximo: ')
print(ser_1.max())
print('Desviación estándar: ')
print(ser_1.std())
print('Cuantiles: ')
print(ser_1.quantile([0.2, 0.4, 0.6,0.8]))
print('Conteo de valores: ')
print(ser_1.value_counts())
print('Conteo de valores porcentuales: ')
print(ser_1.value_counts(normalize=True)*100)
print('Valores distintos listados: ')
print(ser_1.unique())
print('Valores distintos ordenados: ')
print(np.sort(ser_1.unique()))
# Out:
# Suma:
# 41
# Promedio:
# 4.1
# Mediana:
# 4.0
# Mínimo:
# 0
# Máximo:
# 9
# Desviación estándar:
# 3.142893217686178
# Cuantiles:
# 0.2    1.0
# 0.4    3.2
# 0.6    4.4
# 0.8    7.2
# dtype: float64
# Conteo de valores:
# 1    2
# 4    2
# 9    1
# 5    1
# 7    1
# 0    1
# 2    1
# 8    1
# Name: count, dtype: int64
# Conteo de valores porcentuales:
# 1    20.0
# 4    20.0
# 9    10.0
# 5    10.0
# 7    10.0
# 0    10.0
# 2    10.0
# 8    10.0
# Name: proportion, dtype: float64
# Valores distintos listados:
# [9 5 7 1 4 0 2 8]
# Valores distintos ordenados:
# [0 1 2 4 5 7 8 9]

# %%
ser_1.sort_values() #ordenar de manera aleatoria
# Out:
# f    0
# d    1
# i    1
# h    2
# e    4
# g    4
# b    5
# c    7
# j    8
# a    9
# dtype: int32

# %%
ser_1.sort_values(ascending=False) #ordenar de manera ascendente
# Out:
# a    9
# j    8
# c    7
# b    5
# e    4
# g    4
# h    2
# d    1
# i    1
# f    0
# dtype: int32

# %%
ser_1.sort_index() #ordenar por indices
# Out:
# a    9
# b    5
# c    7
# d    1
# e    4
# f    0
# g    4
# h    2
# i    1
# j    8
# dtype: int32

# %%
ser_1.sort_index(ascending=False) #ordenar indices de manera descendente
# Out:
# j    8
# i    1
# h    2
# g    4
# f    0
# e    4
# d    1
# c    7
# b    5
# a    9
# dtype: int32

# %%
#las series pueden ser tratadas como arrays
ser_1 + 1  #sumar un escalar
# Out:
# a    10
# b     6
# c     8
# d     2
# e     5
# f     1
# g     5
# h     3
# i     2
# j     9
# dtype: int32

# %%
np.sqrt(ser_1) # se puede aplicarle funciones matemáticas
# Out:
# a    3.000000
# b    2.236068
# c    2.645751
# d    1.000000
# e    2.000000
# f    0.000000
# g    2.000000
# h    1.414214
# i    1.000000
# j    2.828427
# dtype: float64

# %%
np.exp(ser_1)
# Out:
# a    8103.083928
# b     148.413159
# c    1096.633158
# d       2.718282
# e      54.598150
# f       1.000000
# g      54.598150
# h       7.389056
# i       2.718282
# j    2980.957987
# dtype: float64

# %%
pd.concat([ser_1,pd.Series(10)])
# Out:
# a     9
# b     5
# c     7
# d     1
# e     4
# f     0
# g     4
# h     2
# i     1
# j     8
# 0    10
# dtype: int64

# %%
ser_1 = pd.concat([ser_1,pd.Series(10, index=['k'])])
ser_1
# Out:
# a     9
# b     5
# c     7
# d     1
# e     4
# f     0
# g     4
# h     2
# i     1
# j     8
# k    10
# dtype: int64

# %%
ser_x = pd.Series(np.random.randint(0,20,3), index=['a','b','c'])
ser_y = pd.Series(np.random.randint(0,20,3), index=['b','c','d'])
print(ser_x)
print('--------------------------')
print(ser_y)
print('--------------------------')
print(ser_x+ser_y)
print('--------------------------')
print(ser_x.add(ser_y, fill_value=0))  # fill_value=0, si no encuentras un indice, rellenalo con cero, también se puede aplicar sub, mul y div
# Out:
# a     4
# b    12
# c    11
# dtype: int32
# --------------------------
# b    15
# c     8
# d     8
# dtype: int32
# --------------------------
# a     NaN
# b    27.0
# c    19.0
# d     NaN
# dtype: float64
# --------------------------
# a     4.0
# b    27.0
# c    19.0
# d     8.0
# dtype: float64

# %%
import matplotlib.pyplot as plt

ax = ser_1.plot()
ax.set_xlabel('Index') # leyenda eje x
ax.set_ylabel('Valor') # leyenda eje y
ax.set_title('Mi primer gráfico') # título de gráfico
plt.show()

# %% [markdown]
# ## Data Frames

# %% [markdown]
# Un **DataFrame** son estructuras bidimensionales donde las columnas está etiquetadas con su valor y pueden ser de tipos distintos. Una analogía a un Dataframe podria ser una hoja de cálculo Excel o una tabla de una base de datos.
#
# De forma opcional un Dataframe puede tener un índice. Ese índice será el nombre de las filas.

# %% [markdown]
# #### Creación de un campo de fechas usando pandas

# %%
#date_range genera una lista de fechas.
dates = pd.date_range(start = '20180101',periods=10)
print(dates)
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04',
#                '2018-01-05', '2018-01-06', '2018-01-07', '2018-01-08',
#                '2018-01-09', '2018-01-10'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# https://pandas.pydata.org/docs/user_guide/timeseries.html#timeseries-offset-aliases

# %% [markdown]
# #### Continuamos con creación de dataframes:
#
# Integramos el campo de fecha como índice de un dataframe

# %%
dates = pd.date_range(start = '20180101',periods=10)

# %%
#index=> es el índice y indica el nombre de cada fila. en este caso metemos
#el array de dates del paso anterior. Columns identifica la etiqueta de las
#columnas.
df = pd.DataFrame(np.random.randint(0,100,(10,10)),index=dates,columns=list('ABCDEFGHIJ'))
df   # alternativamente se puede usar display(df)
# Out:
#              A   B   C   D   E   F   G   H   I   J
# 2018-01-01  34  74  64  39  13  97   6   7  27  66
# 2018-01-02   1  13  49  66  21   7  67   1  30  77
# 2018-01-03  76  27  68  35  56  82  87   2  83  26
# 2018-01-04  44  10  79   3  40  47  56  17  79  24
# 2018-01-05  42  95  76  77  88  41  43   6  73  49
# 2018-01-06   0  27  30   3  13  94  68  17  96  68
# 2018-01-07   8  81  25  71  68  55  75  31  50  72
# 2018-01-08  39   2  38  29  33  72  40  68  26  15
# 2018-01-09  30  48  20  65  76  44  25  84  81  97
# 2018-01-10  56  88  50  36  19  73  89  12  68   4

# %%
print(df)
# Out:
#              A   B   C   D   E   F   G   H   I   J
# 2018-01-01  34  74  64  39  13  97   6   7  27  66
# 2018-01-02   1  13  49  66  21   7  67   1  30  77
# 2018-01-03  76  27  68  35  56  82  87   2  83  26
# 2018-01-04  44  10  79   3  40  47  56  17  79  24
# 2018-01-05  42  95  76  77  88  41  43   6  73  49
# 2018-01-06   0  27  30   3  13  94  68  17  96  68
# 2018-01-07   8  81  25  71  68  55  75  31  50  72
# 2018-01-08  39   2  38  29  33  72  40  68  26  15
# 2018-01-09  30  48  20  65  76  44  25  84  81  97
# 2018-01-10  56  88  50  36  19  73  89  12  68   4

# %%
display(df)  # solo para pandas dataframes
# Out:
#              A   B   C   D   E   F   G   H   I   J
# 2018-01-01  34  74  64  39  13  97   6   7  27  66
# 2018-01-02   1  13  49  66  21   7  67   1  30  77
# 2018-01-03  76  27  68  35  56  82  87   2  83  26
# 2018-01-04  44  10  79   3  40  47  56  17  79  24
# 2018-01-05  42  95  76  77  88  41  43   6  73  49
# 2018-01-06   0  27  30   3  13  94  68  17  96  68
# 2018-01-07   8  81  25  71  68  55  75  31  50  72
# 2018-01-08  39   2  38  29  33  72  40  68  26  15
# 2018-01-09  30  48  20  65  76  44  25  84  81  97
# 2018-01-10  56  88  50  36  19  73  89  12  68   4

# %% [markdown]
# #### Principales funciones con dataframes:
#
# A continuación se muestran diversas funciones útiles para acceder a las
# características de un DataFrame

# %%
print(df.index)
print('----------------------------------------')
print(df.columns)
print('----------------------------------------')
print(df.values)
print('----------------------------------------')
display(df)   # solo funciona en jupyters notebooks
print("=========================================")
print(df.describe())    #principales estadisticos de un dataframe
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04',
#                '2018-01-05', '2018-01-06', '2018-01-07', '2018-01-08',
#                '2018-01-09', '2018-01-10'],
#               dtype='datetime64[ns]', freq='D')
# ----------------------------------------
# Index(['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J'], dtype='object')
# ----------------------------------------
# [[34 74 64 39 13 97  6  7 27 66]
#  [ 1 13 49 66 21  7 67  1 30 77]
#  [76 27 68 35 56 82 87  2 83 26]
#  [44 10 79  3 40 47 56 17 79 24]
#  [42 95 76 77 88 41 43  6 73 49]
#  [ 0 27 30  3 13 94 68 17 96 68]
#  [ 8 81 25 71 68 55 75 31 50 72]
#  [39  2 38 29 33 72 40 68 26 15]
#  [30 48 20 65 76 44 25 84 81 97]
#  [56 88 50 36 19 73 89 12 68  4]]
# ----------------------------------------
#              A   B   C   D   E   F   G   H   I   J
# 2018-01-01  34  74  64  39  13  97   6   7  27  66
# 2018-01-02   1  13  49  66  21   7  67   1  30  77
# 2018-01-03  76  27  68  35  56  82  87   2  83  26
# 2018-01-04  44  10  79   3  40  47  56  17  79  24
# 2018-01-05  42  95  76  77  88  41  43   6  73  49
# 2018-01-06   0  27  30   3  13  94  68  17  96  68
# 2018-01-07   8  81  25  71  68  55  75  31  50  72
# 2018-01-08  39   2  38  29  33  72  40  68  26  15
# 2018-01-09  30  48  20  65  76  44  25  84  81  97
# 2018-01-10  56  88  50  36  19  73  89  12  68   4
# =========================================
#                A          B        C          D          E          F  \
# count  10.000000  10.000000  10.0000  10.000000  10.000000  10.000000
# mean   33.000000  46.500000  49.9000  42.400000  42.700000  61.200000
# std    24.413111  35.305807  21.3617  26.821219  27.640751  27.744068
# min     0.000000   2.000000  20.0000   3.000000  13.000000   7.000000
# 25%    13.500000  16.500000  32.0000  30.500000  19.500000  44.750000
# 50%    36.500000  37.500000  49.5000  37.500000  36.500000  63.500000
# 75%    43.500000  79.250000  67.0000  65.750000  65.000000  79.750000
# max    76.000000  95.000000  79.0000  77.000000  88.000000  97.000000
#
#                G          H          I          J
# count  10.000000  10.000000  10.000000  10.000000
# mean   55.600000  24.500000  61.300000  49.800000
# std    26.998765  28.772093  26.008759  30.904153
# min     6.000000   1.000000  26.000000   4.000000
# 25%    40.750000   6.250000  35.000000  24.500000
# 50%    61.500000  14.500000  70.500000  57.500000
# 75%    73.250000  27.500000  80.500000  71.000000
# max    89.000000  84.000000  96.000000  97.000000

# %%
#dataframe transpuesto
df.T
# Out:
#    2018-01-01  2018-01-02  2018-01-03  2018-01-04  2018-01-05  2018-01-06  \
# A          34           1          76          44          42           0
# B          74          13          27          10          95          27
# C          64          49          68          79          76          30
# D          39          66          35           3          77           3
# E          13          21          56          40          88          13
# F          97           7          82          47          41          94
# G           6          67          87          56          43          68
# H           7           1           2          17           6          17
# I          27          30          83          79          73          96
# J          66          77          26          24          49          68
#
#    2018-01-07  2018-01-08  2018-01-09  2018-01-10
# A           8          39          30          56
# B          81           2          48          88
# C          25          38          20          50
# D          71          29          65          36
# E          68          33          76          19
# F          55          72          44          73
# G          75          40          25          89
# H          31          68          84          12
# I          50          26          81          68
# J          72          15          97           4

# %%
df.T.describe()
# Out:
#        2018-01-01  2018-01-02  2018-01-03  2018-01-04  2018-01-05  2018-01-06  \
# count   10.000000   10.000000   10.000000   10.000000   10.000000   10.000000
# mean    42.700000   33.200000   54.200000   39.900000   59.000000   41.600000
# std     31.205591   29.275701   29.768738   26.701852   27.333333   36.652118
# min      6.000000    1.000000    2.000000    3.000000    6.000000    0.000000
# 25%     16.500000    8.500000   29.000000   18.750000   42.250000   14.000000
# 50%     36.500000   25.500000   62.000000   42.000000   61.000000   28.500000
# 75%     65.500000   61.750000   80.500000   53.750000   76.750000   68.000000
# max     97.000000   77.000000   87.000000   79.000000   95.000000   96.000000
#
#        2018-01-07  2018-01-08  2018-01-09  2018-01-10
# count   10.000000   10.000000   10.000000   10.000000
# mean    53.600000   36.200000   57.000000   49.500000
# std     24.676575   21.353116   27.288581   30.855398
# min      8.000000    2.000000   20.000000    4.000000
# 25%     35.750000   26.750000   33.500000   23.250000
# 50%     61.500000   35.500000   56.500000   53.000000
# 75%     71.750000   39.750000   79.750000   71.750000
# max     81.000000   72.000000   97.000000   89.000000

# %% [markdown]
# #### Ordenar un dataframe

# %%
#Ordenar por índices
display(df)
display(df.sort_index(axis=0,ascending=False)) # ordena las filas (axis 0)
display(df.sort_index(axis=1,ascending=False)) # ordena las columnas (axis 1)
display(df.sort_index(axis=1,ascending=False).sort_index(axis=0,ascending=False))
# Out:
#              A   B   C   D   E   F   G   H   I   J
# 2018-01-01  34  74  64  39  13  97   6   7  27  66
# 2018-01-02   1  13  49  66  21   7  67   1  30  77
# 2018-01-03  76  27  68  35  56  82  87   2  83  26
# 2018-01-04  44  10  79   3  40  47  56  17  79  24
# 2018-01-05  42  95  76  77  88  41  43   6  73  49
# 2018-01-06   0  27  30   3  13  94  68  17  96  68
# 2018-01-07   8  81  25  71  68  55  75  31  50  72
# 2018-01-08  39   2  38  29  33  72  40  68  26  15
# 2018-01-09  30  48  20  65  76  44  25  84  81  97
# 2018-01-10  56  88  50  36  19  73  89  12  68   4
#              A   B   C   D   E   F   G   H   I   J
# 2018-01-10  56  88  50  36  19  73  89  12  68   4
# 2018-01-09  30  48  20  65  76  44  25  84  81  97
# 2018-01-08  39   2  38  29  33  72  40  68  26  15
# 2018-01-07   8  81  25  71  68  55  75  31  50  72
# 2018-01-06   0  27  30   3  13  94  68  17  96  68
# 2018-01-05  42  95  76  77  88  41  43   6  73  49
# 2018-01-04  44  10  79   3  40  47  56  17  79  24
# 2018-01-03  76  27  68  35  56  82  87   2  83  26
# 2018-01-02   1  13  49  66  21   7  67   1  30  77
# 2018-01-01  34  74  64  39  13  97   6   7  27  66
#              J   I   H   G   F   E   D   C   B   A
# 2018-01-01  66  27   7   6  97  13  39  64  74  34
# 2018-01-02  77  30   1  67   7  21  66  49  13   1
# 2018-01-03  26  83   2  87  82  56  35  68  27  76
# 2018-01-04  24  79  17  56  47  40   3  79  10  44
# 2018-01-05  49  73   6  43  41  88  77  76  95  42
# 2018-01-06  68  96  17  68  94  13   3  30  27   0
# 2018-01-07  72  50  31  75  55  68  71  25  81   8
# 2018-01-08  15  26  68  40  72  33  29  38   2  39
# 2018-01-09  97  81  84  25  44  76  65  20  48  30
# 2018-01-10   4  68  12  89  73  19  36  50  88  56
#              J   I   H   G   F   E   D   C   B   A
# 2018-01-10   4  68  12  89  73  19  36  50  88  56
# 2018-01-09  97  81  84  25  44  76  65  20  48  30
# 2018-01-08  15  26  68  40  72  33  29  38   2  39
# 2018-01-07  72  50  31  75  55  68  71  25  81   8
# 2018-01-06  68  96  17  68  94  13   3  30  27   0
# 2018-01-05  49  73   6  43  41  88  77  76  95  42
# 2018-01-04  24  79  17  56  47  40   3  79  10  44
# 2018-01-03  26  83   2  87  82  56  35  68  27  76
# 2018-01-02  77  30   1  67   7  21  66  49  13   1
# 2018-01-01  66  27   7   6  97  13  39  64  74  34

# %%
#Ordenar por columnas
#display(df)
display(df.sort_values(by=['C'],ascending=True))
# selecciona la columna que utilizaremos como criterio de ordenación
# Out:
#              A   B   C   D   E   F   G   H   I   J
# 2018-01-09  30  48  20  65  76  44  25  84  81  97
# 2018-01-07   8  81  25  71  68  55  75  31  50  72
# 2018-01-06   0  27  30   3  13  94  68  17  96  68
# 2018-01-08  39   2  38  29  33  72  40  68  26  15
# 2018-01-02   1  13  49  66  21   7  67   1  30  77
# 2018-01-10  56  88  50  36  19  73  89  12  68   4
# 2018-01-01  34  74  64  39  13  97   6   7  27  66
# 2018-01-03  76  27  68  35  56  82  87   2  83  26
# 2018-01-05  42  95  76  77  88  41  43   6  73  49
# 2018-01-04  44  10  79   3  40  47  56  17  79  24

# %% [markdown]
# Las funciones head y tail nos muestran los primeros y últimos elementos respectivamente. Útiles para resumir el dataframe cuando estos son muy grandes.

# %%
display(df.head())  # por defecto muestra 5
display(df.tail(2))
# Out:
#              A   B   C   D   E   F   G   H   I   J
# 2018-01-01  34  74  64  39  13  97   6   7  27  66
# 2018-01-02   1  13  49  66  21   7  67   1  30  77
# 2018-01-03  76  27  68  35  56  82  87   2  83  26
# 2018-01-04  44  10  79   3  40  47  56  17  79  24
# 2018-01-05  42  95  76  77  88  41  43   6  73  49
#              A   B   C   D   E   F   G   H   I   J
# 2018-01-09  30  48  20  65  76  44  25  84  81  97
# 2018-01-10  56  88  50  36  19  73  89  12  68   4

# %%
display(df.sort_values(by=['C'],ascending=False).head(4)) #ordena de manera descendente los valores de la columna C y muestrame los 4 primeros valores
# Out:
#              A   B   C   D   E   F   G   H   I   J
# 2018-01-04  44  10  79   3  40  47  56  17  79  24
# 2018-01-05  42  95  76  77  88  41  43   6  73  49
# 2018-01-03  76  27  68  35  56  82  87   2  83  26
# 2018-01-01  34  74  64  39  13  97   6   7  27  66

# %% [markdown]
# #### Acceder a una columna.

# %%
display(df['B'])   # también es valido cuando la columna tiene espacios en blanco
display(df.B) # Ojo con los nombres de las columnas que sea palabras con espacio
display(df[['B']])  # devuelve un dataframe
display(df[['B','C','D']])  # devuelve un dataframe
# Out:
# 2018-01-01    74
# 2018-01-02    13
# 2018-01-03    27
# 2018-01-04    10
# 2018-01-05    95
# 2018-01-06    27
# 2018-01-07    81
# 2018-01-08     2
# 2018-01-09    48
# 2018-01-10    88
# Freq: D, Name: B, dtype: int32
# 2018-01-01    74
# 2018-01-02    13
# 2018-01-03    27
# 2018-01-04    10
# 2018-01-05    95
# 2018-01-06    27
# 2018-01-07    81
# 2018-01-08     2
# 2018-01-09    48
# 2018-01-10    88
# Freq: D, Name: B, dtype: int32
#              B
# 2018-01-01  74
# 2018-01-02  13
# 2018-01-03  27
# 2018-01-04  10
# 2018-01-05  95
# 2018-01-06  27
# 2018-01-07  81
# 2018-01-08   2
# 2018-01-09  48
# 2018-01-10  88
#              B   C   D
# 2018-01-01  74  64  39
# 2018-01-02  13  49  66
# 2018-01-03  27  68  35
# 2018-01-04  10  79   3
# 2018-01-05  95  76  77
# 2018-01-06  27  30   3
# 2018-01-07  81  25  71
# 2018-01-08   2  38  29
# 2018-01-09  48  20  65
# 2018-01-10  88  50  36

# %% [markdown]
# #### Acceder a una fila.

# %%
display(df[1:4]) #mostrar 3 primeras filas
# Out:
#              A   B   C   D   E   F   G   H   I   J
# 2018-01-02   1  13  49  66  21   7  67   1  30  77
# 2018-01-03  76  27  68  35  56  82  87   2  83  26
# 2018-01-04  44  10  79   3  40  47  56  17  79  24

# %% [markdown]
# La función **loc()** define una selección a traves de nombres de indices, ya sea por filas o columnas

# %%
df_2 = df.copy()
df_2
# Out:
#              A   B   C   D   E   F   G   H   I   J
# 2018-01-01  34  74  64  39  13  97   6   7  27  66
# 2018-01-02   1  13  49  66  21   7  67   1  30  77
# 2018-01-03  76  27  68  35  56  82  87   2  83  26
# 2018-01-04  44  10  79   3  40  47  56  17  79  24
# 2018-01-05  42  95  76  77  88  41  43   6  73  49
# 2018-01-06   0  27  30   3  13  94  68  17  96  68
# 2018-01-07   8  81  25  71  68  55  75  31  50  72
# 2018-01-08  39   2  38  29  33  72  40  68  26  15
# 2018-01-09  30  48  20  65  76  44  25  84  81  97
# 2018-01-10  56  88  50  36  19  73  89  12  68   4

# %%
#La funcion LOC() se usa para realizar filtrados, genera un sub dataframe, y no altera el dataframe original
display(df)
display(df.loc[pd.Timestamp('2018-01-03')]) #extraer los valores de la fila 2018-01-03
display(df.loc[:,['A','B']]) #selecciona todas las filas y las columnas A y B en una lista
display(df.loc['2018-01-01':'2018-01-02',['A','C']]) #selecciona las filas '2013-01-01' a '2013-01-02' y las columnas A y B
# Out:
#              A   B   C   D   E   F   G   H   I   J
# 2018-01-01  34  74  64  39  13  97   6   7  27  66
# 2018-01-02   1  13  49  66  21   7  67   1  30  77
# 2018-01-03  76  27  68  35  56  82  87   2  83  26
# 2018-01-04  44  10  79   3  40  47  56  17  79  24
# 2018-01-05  42  95  76  77  88  41  43   6  73  49
# 2018-01-06   0  27  30   3  13  94  68  17  96  68
# 2018-01-07   8  81  25  71  68  55  75  31  50  72
# 2018-01-08  39   2  38  29  33  72  40  68  26  15
# 2018-01-09  30  48  20  65  76  44  25  84  81  97
# 2018-01-10  56  88  50  36  19  73  89  12  68   4
# A    76
# B    27
# C    68
# D    35
# E    56
# F    82
# G    87
# H     2
# I    83
# J    26
# Name: 2018-01-03 00:00:00, dtype: int32
#              A   B
# 2018-01-01  34  74
# 2018-01-02   1  13
# 2018-01-03  76  27
# 2018-01-04  44  10
# 2018-01-05  42  95
# 2018-01-06   0  27
# 2018-01-07   8  81
# 2018-01-08  39   2
# 2018-01-09  30  48
# 2018-01-10  56  88
#              A   C
# 2018-01-01  34  64
# 2018-01-02   1  49

# %% [markdown]
# **iloc()** es similar, pero utiliza enteros en vez de los nombres de los campos (podemos aplicar indexing y slicing).

# %%
#permite hacer extracciones y filtrador, pero tomando en cuenta los indices
display(df)
display(df.iloc[3])    # devuelve como resultado una serie
display(df.iloc[[3]])    # devuelve como resultado un dataframe
display(df.iloc[0:2,0:2])
display(df.iloc[[1,2,4],[0,2,3]]) #extrae las filas 1,2,4 y columnas 0,2,3
display(df.iloc[:,[0,2,3]]) #extrae todas las filas y columnas 0,2,3
display(df.iloc[[0,2,4],:]) #extrae las filas 0,2,4 y todas las  columnas
# Out:
#              A   B   C   D   E   F   G   H   I   J
# 2018-01-01  34  74  64  39  13  97   6   7  27  66
# 2018-01-02   1  13  49  66  21   7  67   1  30  77
# 2018-01-03  76  27  68  35  56  82  87   2  83  26
# 2018-01-04  44  10  79   3  40  47  56  17  79  24
# 2018-01-05  42  95  76  77  88  41  43   6  73  49
# 2018-01-06   0  27  30   3  13  94  68  17  96  68
# 2018-01-07   8  81  25  71  68  55  75  31  50  72
# 2018-01-08  39   2  38  29  33  72  40  68  26  15
# 2018-01-09  30  48  20  65  76  44  25  84  81  97
# 2018-01-10  56  88  50  36  19  73  89  12  68   4
# A    44
# B    10
# C    79
# D     3
# E    40
# F    47
# G    56
# H    17
# I    79
# J    24
# Name: 2018-01-04 00:00:00, dtype: int32
#              A   B   C  D   E   F   G   H   I   J
# 2018-01-04  44  10  79  3  40  47  56  17  79  24
#              A   B
# 2018-01-01  34  74
# 2018-01-02   1  13
#              A   C   D
# 2018-01-02   1  49  66
# 2018-01-03  76  68  35
# 2018-01-05  42  76  77
#              A   C   D
# 2018-01-01  34  64  39
# 2018-01-02   1  49  66
# 2018-01-03  76  68  35
# 2018-01-04  44  79   3
# 2018-01-05  42  76  77
# 2018-01-06   0  30   3
# 2018-01-07   8  25  71
# 2018-01-08  39  38  29
# 2018-01-09  30  20  65
# 2018-01-10  56  50  36
#              A   B   C   D   E   F   G  H   I   J
# 2018-01-01  34  74  64  39  13  97   6  7  27  66
# 2018-01-03  76  27  68  35  56  82  87  2  83  26
# 2018-01-05  42  95  76  77  88  41  43  6  73  49

# %% [markdown]
# **Filtrado condicional:** Similar a select where condition de sql. Permite consular solo los valores que cumplan con la condición.

# %%
display(df)
display(df[df.B > 50]) # muestra los valores de la tabla en cuya columna B su valor sea mayor que 0
display(df[(df['B']> 50) & (df.C < 50)])
display(df[df > 50])
# muestra los elementos de la tabla que sean mayores que el valor. El resto serán NaN
# Out:
#              A   B   C   D   E   F   G   H   I   J
# 2018-01-01  34  74  64  39  13  97   6   7  27  66
# 2018-01-02   1  13  49  66  21   7  67   1  30  77
# 2018-01-03  76  27  68  35  56  82  87   2  83  26
# 2018-01-04  44  10  79   3  40  47  56  17  79  24
# 2018-01-05  42  95  76  77  88  41  43   6  73  49
# 2018-01-06   0  27  30   3  13  94  68  17  96  68
# 2018-01-07   8  81  25  71  68  55  75  31  50  72
# 2018-01-08  39   2  38  29  33  72  40  68  26  15
# 2018-01-09  30  48  20  65  76  44  25  84  81  97
# 2018-01-10  56  88  50  36  19  73  89  12  68   4
#              A   B   C   D   E   F   G   H   I   J
# 2018-01-01  34  74  64  39  13  97   6   7  27  66
# 2018-01-05  42  95  76  77  88  41  43   6  73  49
# 2018-01-07   8  81  25  71  68  55  75  31  50  72
# 2018-01-10  56  88  50  36  19  73  89  12  68   4
#             A   B   C   D   E   F   G   H   I   J
# 2018-01-07  8  81  25  71  68  55  75  31  50  72
#                A     B     C     D     E     F     G     H     I     J
# 2018-01-01   NaN  74.0  64.0   NaN   NaN  97.0   NaN   NaN   NaN  66.0
# 2018-01-02   NaN   NaN   NaN  66.0   NaN   NaN  67.0   NaN   NaN  77.0
# 2018-01-03  76.0   NaN  68.0   NaN  56.0  82.0  87.0   NaN  83.0   NaN
# 2018-01-04   NaN   NaN  79.0   NaN   NaN   NaN  56.0   NaN  79.0   NaN
# 2018-01-05   NaN  95.0  76.0  77.0  88.0   NaN   NaN   NaN  73.0   NaN
# 2018-01-06   NaN   NaN   NaN   NaN   NaN  94.0  68.0   NaN  96.0  68.0
# 2018-01-07   NaN  81.0   NaN  71.0  68.0  55.0  75.0   NaN   NaN  72.0
# 2018-01-08   NaN   NaN   NaN   NaN   NaN  72.0   NaN  68.0   NaN   NaN
# 2018-01-09   NaN   NaN   NaN  65.0  76.0   NaN   NaN  84.0  81.0  97.0
# 2018-01-10  56.0  88.0   NaN   NaN   NaN  73.0  89.0   NaN  68.0   NaN

# %%
#df_modificado = df #si realizo algun cambio en df_modificado, tambien los cambios se veran reflejados en el dataframe original
# Para evitar eso es mejor realizar una copia del data frame con df.copy()
df_modificado = df.copy()
df_modificado
# Out:
#              A   B   C   D   E   F   G   H   I   J
# 2018-01-01  34  74  64  39  13  97   6   7  27  66
# 2018-01-02   1  13  49  66  21   7  67   1  30  77
# 2018-01-03  76  27  68  35  56  82  87   2  83  26
# 2018-01-04  44  10  79   3  40  47  56  17  79  24
# 2018-01-05  42  95  76  77  88  41  43   6  73  49
# 2018-01-06   0  27  30   3  13  94  68  17  96  68
# 2018-01-07   8  81  25  71  68  55  75  31  50  72
# 2018-01-08  39   2  38  29  33  72  40  68  26  15
# 2018-01-09  30  48  20  65  76  44  25  84  81  97
# 2018-01-10  56  88  50  36  19  73  89  12  68   4

# %% [markdown]
# **Cruzado de datos (merge)** similar a la que se puede hacer en BBDD con join.

# %%
tabla1 = pd.DataFrame({'key1' : ['A','B','C','D'], 'lval':[1,2,3,4]})
tabla2 = pd.DataFrame({'key2' : ['C','D','E','F'], 'rval':[5,6,7,8]})
display(tabla1)
display(tabla2)
new1 = pd.merge(tabla1,tabla2,left_on='key1',right_on='key2', how="left")
new2 = pd.merge(tabla1,tabla2,left_on='key1',right_on='key2', how="right") 
new3 = pd.merge(tabla1,tabla2,left_on='key1',right_on='key2', how="outer") #muestra todo
new4 = pd.merge(tabla1,tabla2,left_on='key1',right_on='key2', how="inner") #solo muestra los que coinciden
# si el campo para fusionar se llama igual en ambas tablas, basta con poner on=" "
#how : forma en la que combinamos con una intersección o con una unión,
#sólo con la izquierda o sólo con la tabla de la derecha
#left, right, inner o outer.
display(new1)
display(new2)
display(new3)
display(new4)
# Out:
#   key1  lval
# 0    A     1
# 1    B     2
# 2    C     3
# 3    D     4
#   key2  rval
# 0    C     5
# 1    D     6
# 2    E     7
# 3    F     8
#   key1  lval key2  rval
# 0    A     1  NaN   NaN
# 1    B     2  NaN   NaN
# 2    C     3    C   5.0
# 3    D     4    D   6.0
#   key1  lval key2  rval
# 0    C   3.0    C     5
# 1    D   4.0    D     6
# 2  NaN   NaN    E     7
# 3  NaN   NaN    F     8
#   key1  lval key2  rval
# 0    A   1.0  NaN   NaN
# 1    B   2.0  NaN   NaN
# 2    C   3.0    C   5.0
# 3    D   4.0    D   6.0
# 4  NaN   NaN    E   7.0
# 5  NaN   NaN    F   8.0
#   key1  lval key2  rval
# 0    C     3    C     5
# 1    D     4    D     6

# %%
tabla3 = pd.DataFrame({'key1' : ['A','B','C','D'], 'lval':[1,2,3,4],'tval':[100,100,100,100]})
tabla4 = pd.DataFrame({'key2' : ['C','D','E','F'], 'rval':[4,4,7,8],'pval':[100,100,100,100]})
display(tabla3)
display(tabla4)
new5 = pd.merge(tabla1,tabla2,left_on=['key1','lval'],right_on=['key2','rval'], how="inner") #solo los valores que cumplen las 2 condiciones se muestran
display(new5)
# Out:
#   key1  lval  tval
# 0    A     1   100
# 1    B     2   100
# 2    C     3   100
# 3    D     4   100
#   key2  rval  pval
# 0    C     4   100
# 1    D     4   100
# 2    E     7   100
# 3    F     8   100
# Empty DataFrame
# Columns: [key1, lval, key2, rval]
# Index: []

# %% [markdown]
# Pero veo que existe un método llamado **join()**. ¿Tienen la misma funcionalidad?

# %%
tabla1.set_index('key1').join(tabla2.set_index('key2'))
# Out:
#       lval  rval
# key1
# A        1   NaN
# B        2   NaN
# C        3   5.0
# D        4   6.0

# %%
tabla1.set_index('key1').join(tabla2.set_index('key2'),how="inner")
# Out:
#    lval  rval
# C     3     5
# D     4     6

# %% [markdown]
# Pues la respuesta es que **No**. El método `join()` se usa cuando se quiere cruzar dos DataFrames en base a sus índices o en base al(a los) índice(s) de un DataFrame con la(s) columna(s) de la otra.

# %%
tabla1 = pd.DataFrame({'key1' : ['A','B','C','D'], 'valor':[1,2,3,4]})
tabla2 = pd.DataFrame({'key1' : ['C','D','E','F'], 'valor':[5,6,7,8]})

display(tabla1)
display(tabla2)

#para juntar 2 dataframes con la misma estructura
tabla_conjunta = pd.concat([tabla1, tabla2]) #juntar de manera vertical
display(tabla_conjunta)

tabla_conjunta2 = pd.concat([tabla1, tabla2],axis=1) #juntar de manera horizontal
display(tabla_conjunta2)
# Out:
#   key1  valor
# 0    A      1
# 1    B      2
# 2    C      3
# 3    D      4
#   key1  valor
# 0    C      5
# 1    D      6
# 2    E      7
# 3    F      8
#   key1  valor
# 0    A      1
# 1    B      2
# 2    C      3
# 3    D      4
# 0    C      5
# 1    D      6
# 2    E      7
# 3    F      8
#   key1  valor key1  valor
# 0    A      1    C      5
# 1    B      2    D      6
# 2    C      3    E      7
# 3    D      4    F      8

# %%
display(tabla_conjunta.reset_index()) #mantiene los indices originales y pasa a columna
tabla_conjunta.reset_index().drop(columns = 'index') #resetear los indices y los organiza de nuevo
# Out:
#    index key1  valor
# 0      0    A      1
# 1      1    B      2
# 2      2    C      3
# 3      3    D      4
# 4      0    C      5
# 5      1    D      6
# 6      2    E      7
# 7      3    F      8
#   key1  valor
# 0    A      1
# 1    B      2
# 2    C      3
# 3    D      4
# 4    C      5
# 5    D      6
# 6    E      7
# 7    F      8

# %% [markdown]
# #### Agrupaciones
#
# Para hacer agrupaciones, podemos usar **groupby**

# %%
f = pd.DataFrame({'A' : ['foo', 'bar'] * 12,
                   'B' : ['one', 'two', 'three']*8,
                   'val1' : np.random.rand(24),
                   'val2' : np.random.rand(24)})
display(f)
# Out:
#       A      B      val1      val2
# 0   foo    one  0.655123  0.777708
# 1   bar    two  0.981875  0.527786
# 2   foo  three  0.083980  0.747890
# 3   bar    one  0.812128  0.660110
# 4   foo    two  0.641975  0.606749
# 5   bar  three  0.376756  0.207441
# 6   foo    one  0.630391  0.498478
# 7   bar    two  0.462423  0.151037
# 8   foo  three  0.168242  0.764688
# 9   bar    one  0.690424  0.235177
# 10  foo    two  0.322555  0.197268
# 11  bar  three  0.432299  0.701811
# 12  foo    one  0.344356  0.880964
# 13  bar    two  0.955320  0.027690
# 14  foo  three  0.329435  0.865572
# 15  bar    one  0.507484  0.941606
# 16  foo    two  0.783801  0.158512
# 17  bar  three  0.591562  0.395182
# 18  foo    one  0.976240  0.716686
# 19  bar    two  0.179058  0.314132
# 20  foo  three  0.472847  0.141419
# 21  bar    one  0.269879  0.238165
# 22  foo    two  0.928791  0.251077
# 23  bar  three  0.063799  0.316974

# %%
group = f.groupby(['A','B'])
print("-------------")
display(group)
# los grupos no se pueden mostrar directamente,
# group está pensado para ejecutar posteriormente una acción
# por ejemplo sumar
print("-----suma agrupada------")
display(group.sum())
print("-----estadisticos agrupados------")
display(group.describe())
# Out:
# -------------
# -----suma agrupada------
#                val1      val2
# A   B
# bar one    2.279915  2.075058
#     three  1.464415  1.621409
#     two    2.578676  1.020646
# foo one    2.606109  2.873836
#     three  1.054505  2.519568
#     two    2.677122  1.213606
# -----estadisticos agrupados------
#            val1                                                              \
#           count      mean       std       min       25%       50%       75%
# A   B
# bar one     4.0  0.569979  0.236015  0.269879  0.448083  0.598954  0.720850
#     three   4.0  0.366104  0.221145  0.063799  0.298517  0.404527  0.472114
#     two     4.0  0.644669  0.391671  0.179058  0.391582  0.708872  0.961959
# foo one     4.0  0.651527  0.258362  0.344356  0.558882  0.642757  0.735402
#     three   4.0  0.263626  0.172699  0.083980  0.147177  0.248839  0.365288
#     two     4.0  0.669281  0.259117  0.322555  0.562120  0.712888  0.820049
#
#                      val2                                                    \
#                 max count      mean       std       min       25%       50%
# A   B
# bar one    0.812128   4.0  0.518764  0.345414  0.235177  0.237418  0.449137
#     three  0.591562   4.0  0.405352  0.212109  0.207441  0.289591  0.356078
#     two    0.981875   4.0  0.255161  0.216323  0.027690  0.120200  0.232585
# foo one    0.976240   4.0  0.718459  0.161568  0.498478  0.662134  0.747197
#     three  0.472847   4.0  0.629892  0.329770  0.141419  0.596272  0.756289
#     two    0.928791   4.0  0.303402  0.205763  0.158512  0.187579  0.224173
#
#
#                 75%       max
# A   B
# bar one    0.730484  0.941606
#     three  0.471839  0.701811
#     two    0.367546  0.527786
# foo one    0.803522  0.880964
#     three  0.789909  0.865572
#     two    0.339995  0.606749

# %% [markdown]
# Una agrupación directa:

# %%
f.groupby(['A','B']).sum()
# Out:
#                val1      val2
# A   B
# bar one    2.279915  2.075058
#     three  1.464415  1.621409
#     two    2.578676  1.020646
# foo one    2.606109  2.873836
#     three  1.054505  2.519568
#     two    2.677122  1.213606

# %% [markdown]
# Ahora aplicamos un filtro sobre una agrupación (similar al having de SQL):

# %%
agrup = f.groupby(['A','B']).sum()
agrup[agrup.val1 > 2.0]
# Out:
#              val1      val2
# A   B
# bar one  2.279915  2.075058
#     two  2.578676  1.020646
# foo one  2.606109  2.873836
#     two  2.677122  1.213606

# %% [markdown]
# ¿Te acuerdas de las tablas dinámicas de Excel? Pues, DataFrame tiene una funcionalidad parecida, con la función ***pivot_table***

# %%
display(f)
# Out:
#       A      B      val1      val2
# 0   foo    one  0.655123  0.777708
# 1   bar    two  0.981875  0.527786
# 2   foo  three  0.083980  0.747890
# 3   bar    one  0.812128  0.660110
# 4   foo    two  0.641975  0.606749
# 5   bar  three  0.376756  0.207441
# 6   foo    one  0.630391  0.498478
# 7   bar    two  0.462423  0.151037
# 8   foo  three  0.168242  0.764688
# 9   bar    one  0.690424  0.235177
# 10  foo    two  0.322555  0.197268
# 11  bar  three  0.432299  0.701811
# 12  foo    one  0.344356  0.880964
# 13  bar    two  0.955320  0.027690
# 14  foo  three  0.329435  0.865572
# 15  bar    one  0.507484  0.941606
# 16  foo    two  0.783801  0.158512
# 17  bar  three  0.591562  0.395182
# 18  foo    one  0.976240  0.716686
# 19  bar    two  0.179058  0.314132
# 20  foo  three  0.472847  0.141419
# 21  bar    one  0.269879  0.238165
# 22  foo    two  0.928791  0.251077
# 23  bar  three  0.063799  0.316974

# %%
# pivot_table tiene 3 partes: index, columns and values (similar a excel)
# margins se refiere a los subtotales
f_pivote = f.pivot_table(index="A", columns="B", values="val1", aggfunc="mean", margins=True, margins_name='Subtotal')
f_pivote
# Out:
# B              one     three       two  Subtotal
# A
# bar       0.569979  0.366104  0.644669  0.526917
# foo       0.651527  0.263626  0.669281  0.528145
# Subtotal  0.610753  0.314865  0.656975  0.527531

# %%
f_pivote = f.pivot_table(index="A", columns="B", values="val1", aggfunc="sum", margins=False)
f_pivote
# Out:
# B         one     three       two
# A
# bar  2.279915  1.464415  2.578676
# foo  2.606109  1.054505  2.677122

# %%
f_pivote.stack()  #devuelve una serie con los datos apilados
# Out:
# A    B
# bar  one      2.279915
#      three    1.464415
#      two      2.578676
# foo  one      2.606109
#      three    1.054505
#      two      2.677122
# dtype: float64

# %%
a = f_pivote.stack()
a[a>2]
# Out:
# A    B
# bar  one    2.279915
#      two    2.578676
# foo  one    2.606109
#      two    2.677122
# dtype: float64

# %%
f_pivote.stack().unstack()   #regresa al dataframe pivoteado
# Out:
# B         one     three       two
# A
# bar  2.279915  1.464415  2.578676
# foo  2.606109  1.054505  2.677122

# %%
f.stack()
# Out:
# 0   A            foo
#     B            one
#     val1    0.655123
#     val2    0.777708
# 1   A            bar
#               ...
# 22  val2    0.251077
# 23  A            bar
#     B          three
#     val1    0.063799
#     val2    0.316974
# Length: 96, dtype: object

# %%
# podemos haces uns tabla cruzada simple con 2 variables de un dataframe
pd.crosstab(f.A, f.B)
# Out:
# B    one  three  two
# A
# bar    4      4    4
# foo    4      4    4

# %% [markdown]
# ### Importar y exportar datos en formato csv y txt

# %%
# Importar datos en formato csv.
# el parámetro encoding se usa para poder cargar texto con otra codificación
# UTF-8(8-bit Unicode Transformation Format) permite cargar caracteres especiales
# (tildes y la letra ñ)
d_students = pd.read_csv(r'C:\Users\dg_su\OneDrive - Universidad Tecnologica del Peru\Estudios\Cursos\Analisis de Datos\Programa Data Science for Business\codigo\base de datos\students.csv', sep=',', encoding = 'UTF-8')

# %%
# Leer los primeros registros
d_students.head()
# Out:
#    LOCATION CODE  COUNTY                                        AREA NAME  \
# 0          10402  ALBANY  RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT
# 1          10402  ALBANY  RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT
# 2          10402  ALBANY  RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT
# 3          10500  ALBANY                      COHOES CITY SCHOOL DISTRICT
# 4          10500  ALBANY                      COHOES CITY SCHOOL DISTRICT
#
#                   REGION SCHOOL YEARS  NO. OVERWEIGHT PCT OVERWEIGHT  \
# 0  NORTHEASTERN NEW YORK    2012-2013           124.0          18.5%
# 1  NORTHEASTERN NEW YORK    2012-2013            74.0          19.2%
# 2  NORTHEASTERN NEW YORK    2012-2013            50.0          17.6%
# 3  NORTHEASTERN NEW YORK    2012-2013            84.0          17.2%
# 4  NORTHEASTERN NEW YORK    2012-2013            58.0          16.1%
#
#    NO. OBESE PCT OBESE  NO. OVERWEIGHT OR OBESE PCT OVERWEIGHT OR OBESE  \
# 0      139.0     20.8%                    263.0                   39.3%
# 1       72.0     18.7%                    146.0                   37.9%
# 2       67.0     23.6%                    117.0                   41.2%
# 3      124.0     25.4%                    208.0                   42.5%
# 4       89.0     24.7%                    147.0                   40.8%
#
#       GRADE LEVEL        AREA TYPE  STREET ADDRESS    CITY STATE  ZIP CODE  \
# 0  DISTRICT TOTAL  SCHOOL DISTRICT  15 MOUNTAIN RD  RAVENA    NY   12143.0
# 1      ELEMENTARY  SCHOOL DISTRICT  15 MOUNTAIN RD  RAVENA    NY   12143.0
# 2     MIDDLE/HIGH  SCHOOL DISTRICT  15 MOUNTAIN RD  RAVENA    NY   12143.0
# 3  DISTRICT TOTAL  SCHOOL DISTRICT      7 BEVAN ST  COHOES    NY   12047.0
# 4      ELEMENTARY  SCHOOL DISTRICT      7 BEVAN ST  COHOES    NY   12047.0
#
#                                           Location 1
# 0  15 MOUNTAIN RD\nRAVENA, NY 12143\n(42.47227638...
# 1  15 MOUNTAIN RD\nRAVENA, NY 12143\n(42.47227638...
# 2  15 MOUNTAIN RD\nRAVENA, NY 12143\n(42.47227638...
# 3  7 BEVAN ST\nCOHOES, NY 12047\n(42.771285452000...
# 4  7 BEVAN ST\nCOHOES, NY 12047\n(42.771285452000...

# %%
# Importar datos en formato txt.
#d_txt = pd.read_csv('data/students.txt', sep='|', encoding = 'UTF-8')

# %%
# Importar datos en formato txt. tomar en cuenta el tipo de separador que utiliza el archivo 
d_txt = pd.read_csv(r'C:\Users\dg_su\OneDrive - Universidad Tecnologica del Peru\Estudios\Cursos\Analisis de Datos\Programa Data Science for Business\codigo\base de datos\students.txt', sep='|', encoding = 'UTF-8')

# %%
d_txt.head()
# Out:
#    LOCATION CODE  COUNTY                                        AREA NAME  \
# 0          10402  ALBANY  RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT
# 1          10402  ALBANY  RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT
# 2          10402  ALBANY  RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT
# 3          10500  ALBANY                      COHOES CITY SCHOOL DISTRICT
# 4          10500  ALBANY                      COHOES CITY SCHOOL DISTRICT
#
#                   REGION SCHOOL YEARS  NO. OVERWEIGHT PCT OVERWEIGHT  \
# 0  NORTHEASTERN NEW YORK    2012-2013           124.0          18.5%
# 1  NORTHEASTERN NEW YORK    2012-2013            74.0          19.2%
# 2  NORTHEASTERN NEW YORK    2012-2013            50.0          17.6%
# 3  NORTHEASTERN NEW YORK    2012-2013            84.0          17.2%
# 4  NORTHEASTERN NEW YORK    2012-2013            58.0          16.1%
#
#    NO. OBESE PCT OBESE  NO. OVERWEIGHT OR OBESE PCT OVERWEIGHT OR OBESE  \
# 0      139.0     20.8%                    263.0                   39.3%
# 1       72.0     18.7%                    146.0                   37.9%
# 2       67.0     23.6%                    117.0                   41.2%
# 3      124.0     25.4%                    208.0                   42.5%
# 4       89.0     24.7%                    147.0                   40.8%
#
#       GRADE LEVEL        AREA TYPE  STREET ADDRESS    CITY STATE  ZIP CODE  \
# 0  DISTRICT TOTAL  SCHOOL DISTRICT  15 MOUNTAIN RD  RAVENA    NY   12143.0
# 1      ELEMENTARY  SCHOOL DISTRICT  15 MOUNTAIN RD  RAVENA    NY   12143.0
# 2     MIDDLE/HIGH  SCHOOL DISTRICT  15 MOUNTAIN RD  RAVENA    NY   12143.0
# 3  DISTRICT TOTAL  SCHOOL DISTRICT      7 BEVAN ST  COHOES    NY   12047.0
# 4      ELEMENTARY  SCHOOL DISTRICT      7 BEVAN ST  COHOES    NY   12047.0
#
#                                           Location 1
# 0  15 MOUNTAIN RD\nRAVENA, NY 12143\n(42.47227638...
# 1  15 MOUNTAIN RD\nRAVENA, NY 12143\n(42.47227638...
# 2  15 MOUNTAIN RD\nRAVENA, NY 12143\n(42.47227638...
# 3  7 BEVAN ST\nCOHOES, NY 12047\n(42.771285452000...
# 4  7 BEVAN ST\nCOHOES, NY 12047\n(42.771285452000...

# %% [markdown]
# ### Exportar datos de un data frame a un csv y txt

# %%
display(f)
# Out:
#       A      B      val1      val2
# 0   foo    one  0.655123  0.777708
# 1   bar    two  0.981875  0.527786
# 2   foo  three  0.083980  0.747890
# 3   bar    one  0.812128  0.660110
# 4   foo    two  0.641975  0.606749
# 5   bar  three  0.376756  0.207441
# 6   foo    one  0.630391  0.498478
# 7   bar    two  0.462423  0.151037
# 8   foo  three  0.168242  0.764688
# 9   bar    one  0.690424  0.235177
# 10  foo    two  0.322555  0.197268
# 11  bar  three  0.432299  0.701811
# 12  foo    one  0.344356  0.880964
# 13  bar    two  0.955320  0.027690
# 14  foo  three  0.329435  0.865572
# 15  bar    one  0.507484  0.941606
# 16  foo    two  0.783801  0.158512
# 17  bar  three  0.591562  0.395182
# 18  foo    one  0.976240  0.716686
# 19  bar    two  0.179058  0.314132
# 20  foo  three  0.472847  0.141419
# 21  bar    one  0.269879  0.238165
# 22  foo    two  0.928791  0.251077
# 23  bar  three  0.063799  0.316974

# %%
#importar como un archivo csv
f.to_csv('data_import\prueba.csv', sep=',', index=False)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\p'
# <>:2: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\dg_su\AppData\Local\Temp\ipykernel_19368\2202352025.py:2: SyntaxWarning: invalid escape sequence '\p'
#   f.to_csv('data_import\prueba.csv', sep=',', index=False)

# %%
f.to_csv('data_import\prueba.txt', sep='|', index=False)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\dg_su\AppData\Local\Temp\ipykernel_19368\3236132228.py:1: SyntaxWarning: invalid escape sequence '\p'
#   f.to_csv('data_import\prueba.txt', sep='|', index=False)

# %% [markdown]
# ### Ejemplo de uso de **read_csv** con *parse_dates*

# %%
import datetime as dt
dateparse = lambda x: dt.datetime.strptime(x, '%Y %m')
# depende del formato que tenga la fecha en tu archivo
data = pd.read_csv(r"C:\Users\dg_su\OneDrive - Universidad Tecnologica del Peru\Estudios\Cursos\Analisis de Datos\Programa Data Science for Business\codigo\base de datos\AirPassengers_2012_2016_2.csv",
                   parse_dates= {'yearmonth':['Year', 'Month']},
                   date_parser=dateparse,
                   index_col='yearmonth')
data.head()
# Out:
# C:\Users\dg_su\AppData\Local\Temp\ipykernel_19368\3040847904.py:4: FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
#   data = pd.read_csv(r"C:\Users\dg_su\OneDrive - Universidad Tecnologica del Peru\Estudios\Cursos\Analisis de Datos\Programa Data Science for Business\codigo\base de datos\AirPassengers_2012_2016_2.csv",
# C:\Users\dg_su\AppData\Local\Temp\ipykernel_19368\3040847904.py:4: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   data = pd.read_csv(r"C:\Users\dg_su\OneDrive - Universidad Tecnologica del Peru\Estudios\Cursos\Analisis de Datos\Programa Data Science for Business\codigo\base de datos\AirPassengers_2012_2016_2.csv",
#               DOMESTIC INTERNATIONAL       TOTAL
# yearmonth
# 2002-10-01  48,054,917     9,578,435  57,633,352
# 2002-11-01  44,850,246     9,016,535  53,866,781
# 2002-12-01  49,684,353    10,038,794  59,723,147
# 2003-01-01  43,032,450     9,726,436  52,758,886
# 2003-02-01  41,166,780     8,283,372  49,450,152

# %% [markdown]
# ### Importar y exportar datos en formato xls/xlsx

# %%
pip install xlrd
# Out:
# Requirement already satisfied: xlrd in c:\users\dg_su\appdata\local\programs\python\python312\lib\site-packages (2.0.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Importar datos en formato xls.
d = pd.read_excel(r'C:\Users\dg_su\OneDrive - Universidad Tecnologica del Peru\Estudios\Cursos\Analisis de Datos\Programa Data Science for Business\codigo\base de datos\students.xls') #, sheet_name = 'Hoja1'

# %%
d.head()
# Out:
#    LOCATION CODE  COUNTY                                        AREA NAME  \
# 0          10402  ALBANY  RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT
# 1          10402  ALBANY  RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT
# 2          10402  ALBANY  RAVENA COEYMANS SELKIRK CENTRAL SCHOOL DISTRICT
# 3          10500  ALBANY                      COHOES CITY SCHOOL DISTRICT
# 4          10500  ALBANY                      COHOES CITY SCHOOL DISTRICT
#
#                   REGION SCHOOL YEARS  NO. OVERWEIGHT  PCT OVERWEIGHT  \
# 0  NORTHEASTERN NEW YORK    2012-2013           124.0           0.185
# 1  NORTHEASTERN NEW YORK    2012-2013            74.0           0.192
# 2  NORTHEASTERN NEW YORK    2012-2013            50.0           0.176
# 3  NORTHEASTERN NEW YORK    2012-2013            84.0           0.172
# 4  NORTHEASTERN NEW YORK    2012-2013            58.0           0.161
#
#    NO. OBESE  PCT OBESE  NO. OVERWEIGHT OR OBESE  PCT OVERWEIGHT OR OBESE  \
# 0      139.0      0.208                    263.0                    0.393
# 1       72.0      0.187                    146.0                    0.379
# 2       67.0      0.236                    117.0                    0.412
# 3      124.0      0.254                    208.0                    0.425
# 4       89.0      0.247                    147.0                    0.408
#
#       GRADE LEVEL        AREA TYPE  STREET ADDRESS    CITY STATE  ZIP CODE  \
# 0  DISTRICT TOTAL  SCHOOL DISTRICT  15 MOUNTAIN RD  RAVENA    NY   12143.0
# 1      ELEMENTARY  SCHOOL DISTRICT  15 MOUNTAIN RD  RAVENA    NY   12143.0
# 2     MIDDLE/HIGH  SCHOOL DISTRICT  15 MOUNTAIN RD  RAVENA    NY   12143.0
# 3  DISTRICT TOTAL  SCHOOL DISTRICT      7 BEVAN ST  COHOES    NY   12047.0
# 4      ELEMENTARY  SCHOOL DISTRICT      7 BEVAN ST  COHOES    NY   12047.0
#
#                                           Location 1
# 0  15 MOUNTAIN RD\nRAVENA, NY 12143\n(42.47227638...
# 1  15 MOUNTAIN RD\nRAVENA, NY 12143\n(42.47227638...
# 2  15 MOUNTAIN RD\nRAVENA, NY 12143\n(42.47227638...
# 3  7 BEVAN ST\nCOHOES, NY 12047\n(42.771285452000...
# 4  7 BEVAN ST\nCOHOES, NY 12047\n(42.771285452000...

# %%
 # Importar datos en formato xls.
d = pd.read_excel(r'C:\Users\dg_su\OneDrive - Universidad Tecnologica del Peru\Estudios\Cursos\Analisis de Datos\Programa Data Science for Business\codigo\base de datos\students_2.xls', sheet_name = 'Hoja1')

# %%
d.head()
# Out:
#    id  edad
# 0  12    21
# 1  13    22
# 2  14    23

# %% [markdown]
# ### Exportar datos de un data frame a formato Excel

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\dg_su\appdata\local\programs\python\python312\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\dg_su\appdata\local\programs\python\python312\lib\site-packages (from openpyxl) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#cargar una tabla en formato excel, con el nombre de la hoja modificado
f.to_excel("data_import\prueba.xlsx", sheet_name = 'Tabla')
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\p'
# <>:2: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\dg_su\AppData\Local\Temp\ipykernel_19368\2777938503.py:2: SyntaxWarning: invalid escape sequence '\p'
#   f.to_excel("data_import\prueba.xlsx", sheet_name = 'Tabla')
